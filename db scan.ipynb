# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import DBSCAN

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
df = pd.read_csv("D:\student_clustering.csv")

# %%
x=np.array(df.values)

# %%
clustering = DBSCAN(eps=1,min_samples=2).fit(x)
clustering.labels_
# Out:
# array([ 0,  1,  2,  3,  4,  4,  5,  6,  4,  7,  0,  4,  3,  0,  4,  8,  9,
#        10,  9,  1,  5,  0, 11,  0,  0,  5,  0, 12,  7, 13,  6,  9,  6, 13,
#         8,  8,  6,  4, -1,  1, 14,  8,  2,  0,  6,  6,  7,  4, 12,  4, 15,
#         0,  6,  8,  6,  4,  9,  6,  4,  6, -1,  8,  8,  6,  0, -1,  2, 14,
#         9,  8,  4,  6,  7, 15,  4,  6,  9,  6,  0, 11, 10, -1,  9, 14,  6,
#         0,  6,  4,  6,  4,  6, -1, 11,  0,  8,  7,  6,  8, -1,  6,  4,  0,
#         0, 12,  0,  0, 11,  0,  6,  6,  7,  6,  4,  9, 10,  6,  8,  4,  6,
#         0,  0,  4,  2, 12,  3, 14,  5,  4,  0,  8,  2,  9, 15,  0,  9,  6,
#         4,  0, -1,  8,  7, 14,  9,  0,  0,  6,  0,  6, 16,  0,  6, 14,  6,
#         6,  0,  8,  9,  6,  4,  2,  0, 12,  4, 11,  6,  0,  4, 14,  0, 12,
#        -1,  4,  6,  0,  0,  5,  6,  4,  0,  6,  6,  4,  4, 16,  8,  0,  2,
#        10,  6,  9,  2,  7,  0, 14,  8,  0,  6,  9,  4,  6], dtype=int64)

# %%
cluster = clustering.labels_

# %%
plt.scatter(x[:,0],x[:,1],c=cluster)

# %%
from sklearn.datasets import make_circles
x , y = make_circles(n_samples = 500 ,noise=0.1,factor=0.1,random_state=4)
plt.scatter(x[:,0],x[:,1],c=y,s=50,cmap='bwr')

# %%
clusters= clustering.fit_predict(x)

# %%
plt.scatter(x[:,0],x[:,1],c=clusters,cmap='viridis' ,marker='o')
plt.show()
